# %% [markdown]
# <a href="https://colab.research.google.com/github/pavansai26/softmax-activation-function-implementation-from-scratch/blob/master/SOFTMAX_ACTIVATION_FUNCTION_IMPLEMENTATION_FROM_SCRATCH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# # softmax activation function

# %% [markdown]
# formula

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# implementation

# %%
def softmax(x):
   return np.exp(x) / np.sum(np.exp(x))

# %%
# plot inputs and outputs
from matplotlib import pyplot
 
# rectified linear function

def softmax(x):
   return np.exp(x) / np.sum(np.exp(x))


 
# define a series of inputs
series_in = [x for x in range(-10, 11)]
# calculate outputs for our inputs
series_out = [softmax(x) for x in series_in]
# line plot of raw inputs to rectified outputs
pyplot.plot(series_in, series_out)
pyplot.show()
